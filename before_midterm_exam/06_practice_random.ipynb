# %% [markdown]
# ## 실습 문제: 0과 1 사이의 무작위 숫자 생성하기
#
# **설명**: 파이썬의 `random` 모듈은 무작위 숫자를 생성하는 데 사용됩니다. 이 문제의 목표는 `random.random()` 함수를 사용하여 0.0과 1.0 사이의 부동소수점 난수 하나를 생성하고 화면에 출력하는 것입니다. 이 함수는 파이썬으로 무작위성을 다루는 가장 기본적인 첫걸음입니다.
#
# **요구사항**:
#
#   - `random` 모듈을 임포트하세요.
#   - `random.random()` 함수를 호출하여 0과 1 사이의 무작위 숫자를 생성하고 변수에 저장하세요.
#   - 생성된 숫자를 `print()` 함수를 사용하여 출력하세요.

# %%
import random

def generate_random_number() -> float:
    """
    0.0과 1.0 사이의 무작위 부동소_수점 숫자 한 개를 생성하여 반환합니다.
    """
    # random.random()을 사용하여 무작위 숫자를 생성합니다.
    random_number = 0.0

    # 생성된 숫자를 반환합니다.
    return random_number


# 함수를 호출하여 결과를 확인합니다.
random_number = generate_random_number()
print(f"생성된 무작위 숫자: {random_number}")

# %% [markdown]
# ## 실습 문제: 확률에 따라 동전 던지기
#
# **설명**: 프로그래밍에서 난수는 확률적 결정을 시뮬레이션하는 데 자주 사용됩니다. 예를 들어, 0과 1 사이의 난수를 생성한 후, 그 값이 0.7보다 작을 확률은 70%입니다. 이 원리를 이용하여 `random.random()` 함수와 `if` 조건문을 결합해, 지정된 확률에 따라 "앞면" 또는 "뒷면"을 반환하는 불공정한 동전 던지기 함수를 만들어 봅니다.
#
# **요구사항**:
#
#   - `random.random()`을 사용해 0.0과 1.0 사이의 무작위 부동소수점 숫자를 생성하세요.
#   - `if` 조건문을 사용하여 생성된 난수가 0.7보다 작은지 확인하세요.
#   - 난수가 0.7보다 작으면 "Heads"을 그렇지 않으면 "Tails"을 반환하세요.

# %%
import random

def biased_coin_toss(prob=0.7) -> str:
    """
    주어진 확률(prob)에 따라 "Heads" 또는 "Tails"을 반환합니다.
    기본 확률은 70%입니다.
    """
    # 1. 0.0과 1.0 사이의 무작위 숫자를 생성합니다.
    # 2. random_value가 prob보다 작으면 "Heads"을, 아니면 "Tails"을 반환합니다.
    pass


# 함수를 여러 번 호출하여 결과가 확률에 따라 다르게 나오는지 확인해보세요.
print("동전 던지기 시뮬레이션:")
for _ in range(10):
    result = biased_coin_toss()
    print(f"결과: {result}")

# %% [markdown]
# ## 실습 문제: 균등 분포 데이터 생성 함수 구현
#
# **설명**: Python의 `random` 모듈과 `NumPy` 라이브러리는 유사한 기능을 제공하지만, 사용법과 반환 타입이 다릅니다. 이 실습의 목표는 [0, 1) 범위의 균등 분포 난수를 생성하는 두 가지 방법을 모두 사용하여, 지정된 개수만큼의 데이터를 생성하고 두 가지 결과(Python 리스트와 NumPy 배열)를 모두 반환하는 단일 함수를 완성하는 것입니다.
#
# $$f(x) = \begin{cases} \frac{1}{b-a} & \text{for } a \le x \le b, \\ 0 & \text{for } x < a \text{ or } x > b \end{cases}$$
#
# **요구사항**:
#
#   - `generate_uniform_data` 함수를 완성하세요.
#   - 첫 번째 변수에는 `random.uniform()`을 사용하여 `num_samples` 개수만큼의 난수를 가진 **리스트**를 생성하여 할당하세요.
#   - 두 번째 변수에는 `np.random.rand()`를 사용하여 `num_samples` 개수만큼의 난수를 가진 **NumPy 배열**을 생성하여 할당하세요.
#   - 함수가 최종적으로 이 리스트와 NumPy 배열을 **튜플** 형태로 반환하도록 하세요.

# %%
import random
import numpy as np
import matplotlib.pyplot as plt

def generate_uniform_data(num_samples: int) -> tuple[list[float], np.ndarray]:
    """
    random.uniform과 np.random.rand를 사용하여 두 종류의 균등 분포 데이터를 생성합니다.

    Args:
        num_samples: 생성할 난수의 개수

    Returns:
        (list, np.ndarray) 튜플 형태의 균등 분포 데이터
    """
    # TODO: random.uniform()을 사용하여 num_samples 개의 난수를 가진 리스트를 만드세요.
    data_from_random = []

    # TODO: np.random.rand()를 사용하여 num_samples 개의 난수를 가진 NumPy 배열을 만드세요.
    data_from_numpy = None

    return data_from_random, data_from_numpy



# 위에서 구현한 함수를 호출하여 10000개의 데이터를 생성합니다.
list_data, numpy_data = generate_uniform_data(10000)

# 데이터가 잘 생성되었는지 처음 5개씩 출력하여 확인합니다.
print(f"List data (first 5): {list_data[:5]}")
print(f"NumPy array data (first 5): {numpy_data[:5]}")

fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(12, 5))
ax1.hist(list_data, bins=30, color='skyblue', edgecolor='black')
ax1.set_title("Data from random.uniform()")
ax2.hist(numpy_data, bins=30, color='salmon', edgecolor='black')
ax2.set_title("Data from np.random.rand()")
plt.suptitle("Distribution Visualization")
plt.show()

# %% [markdown]
# ## 실습 문제: 정규 분포 난수 시각화
#
# **설명**: NumPy의 `np.random.randn()` 함수는 머신러닝과 통계에서 매우 중요한 표준 정규 분포(평균 0, 표준편차 1)를 따르는 난수를 생성합니다. 이 실습에서는 이 함수를 사용하여 데이터를 생성하고, Matplotlib 히스토그램으로 시각화하여 정규 분포의 특징적인 '종 모양' 곡선을 직접 확인하는 것을 목표로 합니다.
#
# $$f(x) = \frac{1}{\sqrt{2\pi}} e^{-\frac{1}{2}x^2}$$
#
# **요구사항**:
# - `np.random.randn(10000)`을 호출하여 표준 정규 분포를 따르는 난수 10000개가 담긴 NumPy 배열을 생성하세요.
# - Matplotlib을 사용하여 생성된 데이터의 히스토그램을 그리고, 그래프의 제목을 "Standard Normal Distribution"으로 설정하세요.
# - 히스토그램이 데이터의 평균인 0을 중심으로 대칭적인 종 모양(bell shape)을 형성하는지 확인하고, 이전에 만들었던 균등 분포 히스토그램과 어떻게 다른지 생각해 보세요.

# %%
import numpy as np
import matplotlib.pyplot as plt

def generate_standard_normal_data(num_samples: int) -> np.ndarray:
    """
    표준 정규분포(평균 0, 표준편차 1)를 따르는 난수 데이터를 생성합니다.

    Args:
        num_samples: 생성할 샘플의 개수.

    Returns:
        NumPy 배열 형태의 난수 데이터.
    """
    # 요구사항 1: np.random.randn()을 사용하여 num_samples 개수만큼의 데이터를 생성하여 반환하세요.
    # TODO: 코드를 작성하세요.
    return None


# 1. 데이터 생성 함수 호출
num_samples = 10000
samples = generate_standard_normal_data(num_samples)
plt.hist(samples, bins=30)

# %% [markdown]
# ## 실습 문제: 3차 함수에 노이즈 추가 및 시각화
#
# **설명**: 머신러닝 모델을 훈련할 때, 실제 데이터는 종종 이상적인 함수 관계에 무작위적인 노이즈가 더해진 형태로 나타납니다. 이 실습에서는 3차 함수 $f(x) = x^3 - x^2 + 3$ 라는 '참' 함수를 정의하고, 여기에 정규 분포 노이즈를 추가하여 실제 데이터와 유사한 형태를 만듭니다. 목표는 Matplotlib을 사용하여 원본 함수(선)와 노이즈가 포함된 데이터 포인트(산점도)를 함께 시각화하여 둘의 관계를 파악하는 것입니다.
#
# $$y = x^3 - x^2 + 3$$
#
# **요구사항**:
# - `np.linspace`를 사용하여 -5부터 5까지의 범위에서 100개의 균일한 간격의 점으로 `x` 배열을 생성하세요.
# - 생성된 `x` 값을 사용하여 3차 함수 $y = x^3 - x^2 + 3$를 계산하여 `y` 배열을 만드세요.
# - `np.random.normal` 함수를 사용하여 평균 0, 표준편차 10인 정규 분포 노이즈를 100개 생성하고, 이를 `y` 배열에 더하여 노이즈가 추가된 데이터를 만드세요.
# - Matplotlib을 사용하여 원본 $(x, y)$ 데이터는 선 그래프(`plt.plot`)로, 노이즈가 추가된 데이터는 산점도(`plt.scatter`)로 한 플롯에 함께 그리세요. 이를 통해 부드러운 원본 함수와 그 주변에 흩어진 데이터 포인트를 시각적으로 확인할 수 있습니다.

# %%
import numpy as np
import matplotlib.pyplot as plt

def generate_noisy_data(x_range: tuple, num_points: int, noise_std: float) -> tuple:
    """
    3차 함수 데이터를 생성하고 정규 분포 노이즈를 추가합니다.

    Args:
        x_range (tuple): x값의 (최소, 최대) 범위.
        num_points (int): 생성할 데이터 포인트의 수.
        noise_std (float): 추가할 노이즈의 표준편차.

    Returns:
        (np.ndarray, np.ndarray, np.ndarray): x, y_true, y_noisy 세 개의 NumPy 배열을 담은 튜플.
    """
    # 요구사항 1: np.linspace를 사용하여 x 배열 생성
    # TODO: x_range와 num_points를 사용하여 x 배열을 생성하세요.
    x = None

    # 요구사항 2: 3차 함수를 계산하여 y_true 배열 생성
    # TODO: x를 사용하여 y = x**3 - x**2 + 3을 계산하세요.
    y_true = None

    # 요구사항 3: 정규 분포 노이즈를 생성하고 y_true에 더하기
    # TODO: 평균 0, 표준편차 noise_std인 노이즈를 num_points 개수만큼 생성하세요.
    noise = None
    y_noisy = y_true + noise

    return x, y_true, y_noisy


# 1. 데이터 생성 함수 호출
x_data, y_true_data, y_noisy_data = generate_noisy_data(x_range=(-5, 5), num_points=100, noise_std=10)
plt.plot(x_data, y_true_data, linewidth=2)
plt.scatter(x_data, y_noisy_data, alpha=0.6)
